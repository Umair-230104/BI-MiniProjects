# %%
import pandas as pd

# %%
dataset = r"C:\Users\umair\Progamming Task\Data\CSV\satellites.csv"

df = pd.read_csv(dataset, header = 0)

df
# Out:
#                                                    Name Country_of_Operator  \
# 0                                              AAUSat-3             Denmark
# 1         ABS-1 (LMI-1, Lockheed Martin-Intersputnik-1)       International
# 2              ABS-1A (Koreasat 2, Mugunghwa 2, ABS-1A)       International
# 3     ABS-2i (MBSat, Mobile Broadcasting Satellite, ...          China (PR)
# 4                       ABS-7 (Koreasat 3, Mugungwha 3)       International
# ...                                                 ...                 ...
# 1162                      Zhongxing 22A (Chinastar 22A)          China (PR)
# 1163                         Zhongxing 2A (Chinasat 2A)          China (PR)
# 1164              Zhongxing 9 (Chinasat 9, Chinastar 9)          China (PR)
# 1165                                       Ziyuan 1-02C          China (PR)
# 1166                                    Ziyuan 3 (ZY-3)          China (PR)
#
# ...
