# %%
import pandas as pd

# %%
dataset = r"C:\Users\pejan\BI projecter\mp1\BI-MiniProjects\Data\CSV\satellites.csv"


df = pd.read_csv(dataset, header = 0)

df
# Out:
#                                                    Name Country_of_Operator  \
# 0                                              AAUSat-3             Denmark
# 1         ABS-1 (LMI-1, Lockheed Martin-Intersputnik-1)       International
# 2              ABS-1A (Koreasat 2, Mugunghwa 2, ABS-1A)       International
# 3     ABS-2i (MBSat, Mobile Broadcasting Satellite, ...          China (PR)
# 4                       ABS-7 (Koreasat 3, Mugungwha 3)       International
# ...                                                 ...                 ...
# 1162                      Zhongxing 22A (Chinastar 22A)          China (PR)
# 1163                         Zhongxing 2A (Chinasat 2A)          China (PR)
# 1164              Zhongxing 9 (Chinasat 9, Chinastar 9)          China (PR)
# 1165                                       Ziyuan 1-02C          China (PR)
# 1166                                    Ziyuan 3 (ZY-3)          China (PR)
#
# ...

# %%
df.shape
# Out:
# (1167, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          1167 non-null   object
#  1   Country_of_Operator           1167 non-null   object
#  2   Operator_Owner                1167 non-null   object
#  3   Users                         1167 non-null   object
#  4   Purpose                       1167 non-null   object
#  5   Class_of_Orbit                1167 non-null   object
#  6   Type_of_Orbit                 521 non-null    object
#  7   Perigee_km                    1166 non-null   float64
#  8   Apogee_km                     1166 non-null   float64
#  9   Eccentricity                  1166 non-null   float64
#  10  Period_minutes                1165 non-null   float64
#  11  Launch_Mass_kg                1079 non-null   float64
# ...

# %%
list(df)
# Out:
# ['Name',
#  'Country_of_Operator',
#  'Operator_Owner',
#  'Users',
#  'Purpose',
#  'Class_of_Orbit',
#  'Type_of_Orbit',
#  'Perigee_km',
#  'Apogee_km',
#  'Eccentricity',
#  'Period_minutes',
#  'Launch_Mass_kg',
#  'Dry_Mass_kg',
#  'Power_watts',
#  'Date_of_Launch',
#  'Anticipated_Lifetime',
#  'Contractor',
#  'Country_of_Contractor',
#  'Launch_Site',
#  'Launch_Vehicle',
#  'Source_Used_for_Orbital_Data',
#  'longitude_radians_of_geo',
#  'Inclination_radians']

# %%
df.describe()
# Out:
#          Perigee_km      Apogee_km  Eccentricity  Period_minutes  \
# count   1166.000000    1166.000000   1166.000000     1165.000000
# mean   15507.611492   18385.071184      0.024622      699.522996
# std    16640.114314   28491.018427      0.126123      872.372114
# min      186.000000     317.000000      0.000000        0.220000
# 25%      681.000000     777.250000      0.000210       98.800000
# 50%     1413.000000    1505.500000      0.000420      115.500000
# 75%    35773.000000   35795.000000      0.001640     1436.090000
# max    37782.000000  470310.000000      0.972870    19700.450000
#
#        Launch_Mass_kg   Dry_Mass_kg   Power_watts  Date_of_Launch  \
# count     1079.000000    490.000000    615.000000     1166.000000
# mean      2174.052271   1289.611224   3760.784797    38876.492281
# std       2306.175815   1301.680706   4593.453954     2204.609464
# min          0.800000      1.000000      2.000000    27348.000000
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Country_of_Operator', 'Operator_Owner', 'Users', 'Purpose',
#        'Class_of_Orbit', 'Type_of_Orbit', 'Perigee_km', 'Apogee_km',
#        'Eccentricity', 'Period_minutes', 'Launch_Mass_kg', 'Dry_Mass_kg',
#        'Power_watts', 'Date_of_Launch', 'Anticipated_Lifetime', 'Contractor',
#        'Country_of_Contractor', 'Launch_Site', 'Launch_Vehicle',
#        'Source_Used_for_Orbital_Data', 'longitude_radians_of_geo',
#        'Inclination_radians'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1167, step=1)

# %%
df.isnull().sum()
# Out:
# Name                              0
# Country_of_Operator               0
# Operator_Owner                    0
# Users                             0
# Purpose                           0
# Class_of_Orbit                    0
# Type_of_Orbit                     0
# Perigee_km                        1
# Apogee_km                         1
# Eccentricity                      1
# Period_minutes                    2
# Launch_Mass_kg                   88
# Dry_Mass_kg                     677
# Power_watts                     552
# Date_of_Launch                    1
# Anticipated_Lifetime            289
# Contractor                        6
# Country_of_Contractor             0
# Launch_Site                       0
# Launch_Vehicle                    1
# Source_Used_for_Orbital_Data     28
# longitude_radians_of_geo        736
# Inclination_radians               3
# dtype: int64

# %%
df
# Out:
#                                                    Name Country_of_Operator  \
# 0                                              AAUSat-3             Denmark
# 1         ABS-1 (LMI-1, Lockheed Martin-Intersputnik-1)       International
# 2              ABS-1A (Koreasat 2, Mugunghwa 2, ABS-1A)       International
# 3     ABS-2i (MBSat, Mobile Broadcasting Satellite, ...          China (PR)
# 4                       ABS-7 (Koreasat 3, Mugungwha 3)       International
# ...                                                 ...                 ...
# 1162                      Zhongxing 22A (Chinastar 22A)          China (PR)
# 1163                         Zhongxing 2A (Chinasat 2A)          China (PR)
# 1164              Zhongxing 9 (Chinasat 9, Chinastar 9)          China (PR)
# 1165                                       Ziyuan 1-02C          China (PR)
# 1166                                    Ziyuan 3 (ZY-3)          China (PR)
#
# ...

# %%
df_type_of_orbit = df

df_type_of_orbit['Type_of_Orbit'].unique()
# Out:
# array([nan, 'Sun-Synchronous', 'Deep Highly Eccentric', 'Polar',
#        'Intermediate', 'Molniya', 'Retrograde', 'Cislunar'], dtype=object)

# %%
df_type_of_orbit.Type_of_Orbit.value_counts()
# Out:
# Type_of_Orbit
# 0                        646
# Sun-Synchronous          263
# Intermediate             147
# Polar                     89
# Molniya                   11
# Deep Highly Eccentric      9
# Retrograde                 1
# Cislunar                   1
# Name: count, dtype: int64

# %%
df_type_of_orbit["Type_of_Orbit"].fillna(0, inplace=True)

df_type_of_orbit
# Out:
#                                                    Name Country_of_Operator  \
# 0                                              AAUSat-3             Denmark
# 1         ABS-1 (LMI-1, Lockheed Martin-Intersputnik-1)       International
# 2              ABS-1A (Koreasat 2, Mugunghwa 2, ABS-1A)       International
# 3     ABS-2i (MBSat, Mobile Broadcasting Satellite, ...          China (PR)
# 4                       ABS-7 (Koreasat 3, Mugungwha 3)       International
# ...                                                 ...                 ...
# 1162                      Zhongxing 22A (Chinastar 22A)          China (PR)
# 1163                         Zhongxing 2A (Chinasat 2A)          China (PR)
# 1164              Zhongxing 9 (Chinasat 9, Chinastar 9)          China (PR)
# 1165                                       Ziyuan 1-02C          China (PR)
# 1166                                    Ziyuan 3 (ZY-3)          China (PR)
#
# ...

# %%
df_launch_site = df

df_launch_site['Launch_Site'].unique()
# Out:
# array(['Satish Dhawan Space Center', 'Baikonur Cosmodrome',
#        'Cape Canaveral', 'Guiana Space Center', 'Vandenberg AFB',
#        'Xichang Satellite Launch Center', 'Sriharikota Launch Station',
#        'Plesetsk Cosmodrome', 'Uchinoura Space Center',
#        'Dombarovsky Launch Facility', 'ISS', 'L-1011 Aircraft',
#        'Wallops Island Flight Facility', 'Taiyuan Launch Center',
#        'Jiuquan Satellite Launch Center', 'Sea Launch (Odyssey)',
#        'Sea Launch', 'Tanegashima Space Center', 'Svobodny Cosmodrome',
#        'Kodiak Launch Complex', 'Yasny Cosmodrome', 'Kwajalein Island',
#        'Kennedy Space Center', 'Palmachim Launch Complex',
#        'Naro Space Center'], dtype=object)

# %%
df_launch_site.Launch_Site.value_counts()
# Out:
# Launch_Site
# Baikonur Cosmodrome                246
# Guiana Space Center                188
# Cape Canaveral                     166
# Vandenberg AFB                     140
# Plesetsk Cosmodrome                 82
# Taiyuan Launch Center               53
# Wallops Island Flight Facility      47
# Xichang Satellite Launch Center     47
# Dombarovsky Launch Facility         36
# Jiuquan Satellite Launch Center     35
# Sriharikota Launch Station          33
# Sea Launch (Odyssey)                26
# Tanegashima Space Center            22
# Satish Dhawan Space Center          17
# Kodiak Launch Complex                5
# Sea Launch                           4
# Uchinoura Space Center               4
# Svobodny Cosmodrome                  3
# Kwajalein Island                     3
# Palmachim Launch Complex             3
# ISS                                  2
# Yasny Cosmodrome                     2
# L-1011 Aircraft                      1
# Kennedy Space Center                 1
# ...
