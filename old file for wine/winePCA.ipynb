# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
red_dataset = pd.read_excel('Data/winequality-red.xlsx')
red_dataframe = pd.read_excel('Data/winequality-red.xlsx', header=1)
red_dataframe.drop_duplicates(inplace=True)
red_dataframe['wine_type'] = 'red'
red_dataframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality wine_type
# 0         9.4        5       red
# 1         9.8        5       red
# 2         9.8        5       red
# 3         9.8        6       red
# 5         9.4        5       red
# ...       ...      ...       ...
# 1593      9.5        6       red
# 1594     10.5        5       red
# 1595     11.2        6       red
# 1597     10.2        5       red
# 1598     11.0        6       red
#
# [1359 rows x 13 columns]

# %%
white_dataset = pd.read_excel('Data/winequality-white.xlsx')
white_dataframe = pd.read_excel('Data/winequality-white.xlsx', header=1)
white_dataframe.drop_duplicates(inplace=True)
white_dataframe['wine_type'] = 'white'
white_dataframe
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality wine_type
# 0         8.8        6     white
# 1         9.5        6     white
# 2        10.1        6     white
# 3         9.9        6     white
# 6         9.6        6     white
# ...       ...      ...       ...
# 4893     11.2        6     white
# 4894      9.6        5     white
# 4895      9.4        6     white
# 4896     12.8        7     white
# 4897     11.8        6     white
#
# [3961 rows x 13 columns]

# %%
all_wine = pd.concat([white_dataframe, red_dataframe], ignore_index=True)

# %%
all_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               6.2             0.320         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 5315            6.8             0.620         0.08             1.9      0.068
# 5316            6.2             0.600         0.08             2.0      0.090
# 5317            5.9             0.550         0.10             2.2      0.062
# 5318            5.9             0.645         0.12             2.0      0.075
# 5319            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 5315                 28.0                  38.0  0.99651  3.42       0.82
# 5316                 32.0                  44.0  0.99490  3.45       0.58
# 5317                 39.0                  51.0  0.99512  3.52       0.76
# 5318                 32.0                  44.0  0.99547  3.57       0.71
# 5319                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality wine_type
# 0         8.8        6     white
# 1         9.5        6     white
# 2        10.1        6     white
# 3         9.9        6     white
# 4         9.6        6     white
# ...       ...      ...       ...
# 5315      9.5        6       red
# 5316     10.5        5       red
# 5317     11.2        6       red
# 5318     10.2        5       red
# 5319     11.0        6       red
#
# [5320 rows x 13 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca_data = pca.fit_transform(all_wine.iloc[:, :-1])
pca_data
# Out:
# array([[ 5.83958345e+01,  1.93937225e+00,  1.34756485e+01, ...,
#         -1.84258974e-02, -5.71584443e-03,  4.97956306e-04],
#        [ 1.35883649e+01, -1.97900140e+01, -3.55503685e+00, ...,
#          5.17858364e-02, -8.99124726e-03,  4.84105166e-04],
#        [-1.65789819e+01,  3.94532171e+00,  2.46092897e+00, ...,
#          3.00245350e-02, -2.79430042e-03, -1.42195785e-03],
#        ...,
#        [-5.94067619e+01,  2.32489469e+01, -1.08636200e+00, ...,
#         -2.72927455e-02, -1.71219934e-02,  1.02978594e-03],
#        [-6.78259620e+01,  1.80401553e+01, -7.86694386e-01, ...,
#          4.94214100e-02, -1.77590189e-02, -1.82540462e-04],
#        [-7.29356906e+01,  4.92470534e+00,  1.17539257e+00, ...,
#          1.28073679e-01, -8.29285702e-03,  1.84405400e-03]])

# %%
# The PCA class contains explained variance  ratio, 
# which returns the variance caused by each of the principal components
explained_variance = pca.explained_variance_ratio_  
explained_variance
# Out:
# array([9.54044303e-01, 4.06164483e-02, 4.32004318e-03, 5.08184196e-04,
#        3.55094507e-04, 1.33957942e-04, 8.87979881e-06, 5.65963434e-06,
#        4.23666269e-06, 2.95384902e-06, 2.39248344e-07, 1.64743183e-10])

# %%
# Plot the explained_variance
plt.plot(explained_variance, 'bx-', c='red')
plt.xlabel('component')
plt.ylabel('variance')
plt.title('The optimal number of components')
plt.show()
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6828\1047061413.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bx-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(explained_variance, 'bx-', c='red')

# %%
# Plot the cumulative explained_variance
cumulative = np.cumsum(explained_variance)
plt.plot(cumulative, 'b*-', c='green')
plt.xlabel('components')
plt.ylabel('cumulative')
plt.title('The optimal number of components')
plt.show()
# Out:
# C:\Users\umair\AppData\Local\Temp\ipykernel_6828\1148483022.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(cumulative, 'b*-', c='green')

# %%
pca = PCA(n_components=5)
pca_data = pca.fit_transform(all_wine.iloc[:, :-1])
pca_data
# Out:
# array([[ 5.83958345e+01,  1.93937225e+00,  1.34756485e+01,
#          7.43911331e-02, -2.25991997e-01],
#        [ 1.35883649e+01, -1.97900140e+01, -3.55503685e+00,
#          8.02556639e-03, -1.12644326e+00],
#        [-1.65789819e+01,  3.94532171e+00,  2.46092897e+00,
#          6.72607685e-01,  3.54169133e-01],
#        ...,
#        [-5.94067619e+01,  2.32489469e+01, -1.08636200e+00,
#         -1.26134436e+00, -1.02641008e+00],
#        [-6.78259620e+01,  1.80401553e+01, -7.86694386e-01,
#         -3.98520824e-01, -2.08646193e+00],
#        [-7.29356906e+01,  4.92470534e+00,  1.17539257e+00,
#         -1.40410484e+00, -1.06817611e+00]])

# %%
pcadf = pd.DataFrame(data = pca_data, columns = ['pc 1', 'pc 2', 'pc 3', 'pc 4', 'pc 5'])
pcadf
# Out:
#            pc 1       pc 2       pc 3      pc 4      pc 5
# 0     58.395835   1.939372  13.475648  0.074391 -0.225992
# 1     13.588365 -19.790014  -3.555037  0.008026 -1.126443
# 2    -16.578982   3.945322   2.460929  0.672608  0.354169
# 3     73.943390  -0.034424   0.671028  0.420489  0.326986
# 4     21.364530  -5.048869   1.261590 -0.307535 -0.964592
# ...         ...        ...        ...       ...       ...
# 5315 -74.588205  15.535830  -0.522645  0.293248 -1.510964
# 5316 -67.829526  18.039226  -0.798868 -0.366866 -1.700653
# 5317 -59.406762  23.248947  -1.086362 -1.261344 -1.026410
# 5318 -67.825962  18.040155  -0.786694 -0.398521 -2.086462
# 5319 -72.935691   4.924705   1.175393 -1.404105 -1.068176
#
# [5320 rows x 5 columns]
